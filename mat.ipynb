# %%
import h5py

# Load the .mat file
file_path = 'data/HCTSA_3min_clean_N.mat'
with h5py.File(file_path, 'r') as mat_file:
    # Display the keys in the .mat file
    print("Keys in the .mat file:", list(mat_file.keys()))

    # Access a specific variable from the .mat file
    variable_name = 'TimeSeries'  # Replace with the variable you want to access
    if variable_name in mat_file:
        dat = mat_file[variable_name]
        data = mat_file[variable_name][:]
        print(f"Data from '{variable_name}':", data)
    else:
        print(f"'{variable_name}' not found in the .mat file")
# Out:
# Keys in the .mat file: ['#refs#', '#subsystem#', 'MasterOperations', 'Operations', 'TS_DataMat', 'TS_Quality', 'TimeSeries', 'fromDatabase', 'gitInfo', 'normalizationInfo', 'op_clust', 'ts_clust']
# Data from 'TimeSeries': [[3707764736          2          1          1          1          2]]

# %%
data
# Out:
# array([[0.55423911, 0.5455242 , 0.51924321, ..., 0.41919184, 0.4275617 ,
#         0.28599462],
#        [0.55824675, 0.55403692, 0.52816935, ..., 0.44688676, 0.4483526 ,
#         0.31224263],
#        [0.56765371, 0.55447373, 0.52581651, ..., 0.43908757, 0.46290161,
#         0.30589247],
#        ...,
#        [0.43802096, 0.41094607, 0.37970635, ..., 0.88368766, 0.84369884,
#         0.85507034],
#        [0.46586518, 0.4370244 , 0.40881605, ..., 0.88343446, 0.84426543,
#         0.8537182 ],
#        [0.72635698, 0.70532716, 0.69392668, ..., 0.80437344, 0.75057782,
#         0.76592517]])

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.554239  0.545524  0.519243  0.508755  0.554129  0.540759  0.525746
# 1     0.558247  0.554037  0.528169  0.523946  0.562915  0.553436  0.538850
# 2     0.567654  0.554474  0.525817  0.527050  0.559961  0.555816  0.539916
# 3     0.555212  0.546846  0.520229  0.510549  0.556070  0.542660  0.527838
# 4     0.556208  0.548923  0.521178  0.514140  0.558516  0.545821  0.531423
# ...        ...       ...       ...       ...       ...       ...       ...
# 6059  0.891755  0.826863  0.855636  0.857420  0.819915  0.871395  0.880983
# 6060  0.842355  0.824820  0.836922  0.921148  0.823574  0.914872  0.924405
# 6061  0.438021  0.410946  0.379706  0.320449  0.490950  0.466028  0.412869
# 6062  0.465865  0.437024  0.408816  0.348762  0.518473  0.500313  0.445924
# 6063  0.726357  0.705327  0.693927  0.716560  0.743165  0.770509  0.758881
#
# ...
